# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split(',') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
            
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	# print('Saved: %s' % filename)

# load dataset
# filename = '/content/drive/My Drive/Translator/deu.txt'
# filename = '/content/drive/My Drive/Translator/Data/Data_Autshumato/en_zu_autshumatso.txt' 
filename = './Data/Data_Autshumato/en_zu_autshumatso'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs[1:])
# save clean pairs to file
save_clean_data(clean_pairs, 'english-german.pkl')
# spot check
# print(type(clean_pairs), clean_pairs.shape)
# print(clean_pairs[0])
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# [freedom of artistic creativity] => [inkululeko yokwakha izinto ngokusebenzisa ubuciko]
# [a juristic person is entitled to the rights in the bill of rights to the extent required by the nature of the rights and the nature of that juristic person] => [lezozakhiwo ezithathwa njengabantu ngumthetho zingabanamalungelo akumqulu wamalungelo kuphela ngendlela edingwa uhlobo lwelungelo kanye nolwaleso sakhiwo esithathwa njengomuntu ngumthetho]
# [we the people of south africa recognise the injustices of our past] => [thina bantu baseningizimu afrika siyakukhumbula ukucekelwa phansi kwamalungelo okwenzeka eminyakeni eyadlula]
# [everyone has the right to bodily and psychological integrity which includes the right] => [wonke umuntu unelungelo lokukhululeka nokuhlonishwa komzimba kanye nengqondo okubandakanya ilungelo]
# [when applying a provision of the bill of rights to a natural or juristic person in terms of subsection a court] => [uma isebenzisa izimiso zomqulu wamalungelo kubantu bemvelo nakulezozakhiwo ezithathwa ngumthetho njengabantu ngokubeka kwesigatshana inkantolob]
# [the national anthem of the republic is determined by the president by proclamation] => [iculo lesizwe laseriphabhuliki liyonqunywa ngumongameli ngesimemezelo ephephandabeni likahulumeni lomthetho]
# [no one may be subjected to slavery servitude or forced labour] => [akekho umuntu ongenziwa isigqila asetshenziswe njengesigqila noma asetshenziswe ngenkani]
# [republic of south africa] => [iriphabhuliki yaseningizimu afrika]
# [every citizen is free to make political choices which includes the right] => [yileso naleso sakhamuzi sikhululekile ukuzikhethela nokuzenzela izinqumo eziphathelene nezepolitiki okubandakanya ilungelo]
# [improve the quality of life of all citizens and free the potential of each person] => [sithuthukise izinga lokuphila lazo zonke izakhamuzi futhi sikhulule amakhono omuntu ngamunye]
# [to vote in elections for any legislative body established in terms of the constitution and to do so in secret] => [lokuvota okhethweni lwanoma yisiphi isishayamthetho esisungulwe njengokusho komthethosisekelo futhi lokuvota ngokuyimfihlo]
# [everyone has the right to life] => [wonke umuntu unelungelo lokuphila]
# [all official languages] => [kwazozonke izilimi ezisemthethweni]
# [and to stand for public office and if elected to hold office] => [futhi lokungenela ukhetho lwesikhundla sokumela umphakathi kuthi uma sikhethiwe sithathe leso sikhundla]
# [everyone is equal before the law and has the right to equal protection and benefit of the law] => [wonke umuntu uyalingana phambi komthetho futhi unelungelo elilinganayo lokuvikelwa ngumthetho nenzuzo yomthetho]
# [those observances follow rules made by the appropriate public authorities] => [labo ababambe izinkonzo belandela imitheshwana eyenziwe abaphathi abaqondene naleyo ndawo abafanele]
# [to be free from all forms of violence from either public or private sources] => [lokukhululeka kuzozonke izinhlobo zodlame ezivela ezakhiweni zombuso noma ngasese]
# [freedom of religion belief and opinion] => [inkululeko kwezenkolo inkolelo noma umbono]
# [everyone has the right to freedom and security of the person which includes the right] => [wonke umuntu unelungelo lenkululeko nokuphepha kwakhe okubandakanya ilungelo]
# [application] => [ukusebenza komqulu]
# [supremacy of the constitution and the rule of law] => [ubukhulu bomthethosisekelo nokubusa komthetho okugculisayo]
# [and may develop rules of the common law to limit the right provided that the limitation is in accordance with section] => [futhi ingathuthukisa imitheshwana yomthetho ojwayelekile ukuze ikhawule ilungelo kodwa lowo mkhawulo kufanele uhambisane nesigaba]
# [every adult citizen has the right] => [yileso naleso sakhamuzi esidala sinelungelo]
# [and believe that south africa belongs to all who live in it united in our diversity] => [sikholelwa ekutheni iningizimu afrika ingeyabo bonke abahlala kuyo sibumbene nakuba singefani]
# [and sign language] => [futhi ulimi lokukhuluma ngezimpawu]
# [in order to give effect to a right in the bill must apply or if necessary develop the common law to the extent that legislation does not give effect to that right] => [ukuze ilenze libenomphumela ilungelo elikumqulu inkantolo kufanele ilisebenzise noma uma kunesidingo ithuthukise umthetho ojwayelekile ngendlela ezonika ilungelo umphumela lapho umthetho osemabhukwini ungakwenzi lokhu]
# [preamble] => [isingeniso]
# [and to the extent that it is applicable taking into account the nature of the right and the nature of any duty imposed by the right] => [futhi kungadluli ezingeni okungenzeke ngakho lokhu uma kubhekwe uhlobo lwelungelo nanoma yiziphi izibopho ezibekwa yilelo lungelo]
# [or advocacy of hatred that is based on race] => [ukugqugquzela udlame olufufusayo]
# [may god protect our people] => [sengathi unkulunkulu angabavikela abantu bakithi]
# [but the national government and each provincial government must use at least two official languages] => [kodwa uhulumeni okazwelonke noma owesifundazwe kumele usebenzise izilimi ezimbili ezisemthethweni]
# [honour those who suffered for justice and freedom in our land] => [sibungaza labo abahluphekela ubulungiswa nenkululeko kulo mhlaba wethu]
# [the bill of rights applies to all law and binds the legislature the executive the judiciary and all organs of state] => [umqulu wamalungelo usebenza kuyo yonke imithetho futhi uphoqa isishayamthetho isigungu sokuphatha sikahulumeni abaphethe izinkantolo nazozonke izingxenye zombuso]
# [propaganda for war] => [inkulumo egqugquzelela impi]
# [religious observances may be conducted at state or stateaided institutions provided that] => [izinkonzo zingabanjelwa ezikhungweni zombuso noma kulezo zikhungo ezisizwa ngumbuso ngezimali kodwa uma]
# [the national flag of the republic is black gold green white red and blue as described and sketched in schedule] => [ifulegi lesizwe linombala omnyama osagolide oluhlaza okotshani omhlophe obomvu noluhlaza okwesibhakabhaka njengoba lichazwe futhi ladwetshwa kusheduli]
# [freedom of the press and other media] => [inkululeko yamaphephandaba neminye imithombo yezindaba]
# [political rights] => [amalungelo ezepolitiki]
# [everyone has the right to privacy which includes the right not to have] => [wonke umuntu unelungelo lokungaphazanyiswa okubandakanya ilungelo]
# [equally entitled to the rights privileges and benefits of citizenship] => [zinelungelo elilinganayo lokuthola wonke amalungelo ilungelo mvumo nezinzuzo zobuzwe]
# [human dignity the achievement of equality and the advancement of human rights and freedoms] => [isithunzi somuntu ukusebenzela ukulingana kwabantu nokuthuthukiswa kwamalungelo nenkululeko yabantu]
# [citizenship] => [ubuzwe]
# [all languages commonly used by communities in south africa including german greek gujarati hindi portuguese tamil telegu and urdu] => [kwazo zonke izilimi ezijwayelekile emphakathini waseningizimu afrika ezibandakanya isijalimani isigrikhi isigujerati isihindi isiputukezi isitamil isitelegu isiurdu]
# [heal the divisions of the past and establish a society based on democratic values social justice and fundamental human rights] => [silungise ukwehlukana kwesikhathi esedlule bese sakha umphakathi owesekelwe yinkolelo yenqubo yentando yeningi ubulungiswa emphakathini kanye namalungelo obuntu]
# [this constitution is the supreme law of the republic] => [lomthethosisekelo ungumthetho omkhulu waseriphablikhi]
# [this bill of rights is a cornerstone of democracy in south africa] => [lomqulu wamalungelo uyisisekelo sombuso wenqubo yentando yeningi eningizimu afrika]
# [equality] => [ukulingana]
# [founding provisions] => [ukusekwa komthethosisekelo]
# [privacy] => [ukungaphazanyiswa]
# [the khoi nama and san languages] => [ulimi lwamakhoi amanama namasan]
# [freedom of association] => [ilungelo lokuzibandakanya]
# [and not to be subjected to medical or scientific experiments without their informed consent] => [futhi lokungasetshenziselwa ukufunisela ngezokwelapha noma ngezesayensi ngaphandle kwemvume yakhe]
# [a provision of the bill of rights binds a natural or a juristic person if] => [isimiso kumqulu wamalungelo sibopha abantu bemvelo nalezozakhiwo ezithathwa ngumthetho njengabantu uma]
# [every citizen has the right to free fair and regular elections for any legislative body established in terms of the constitution] => [yileso naleso sakhamuzi sinelungelo lokuthi kubekhona ukhetho olukhululekile nolubanjwa njalo ngezikhathi ezimisiwe lwanoma yisiphi isakhiwo sesishayamthetho esisungulwe ngokulandela umthethosisekelo]
# [not to be detained without trial] => [lokungavalelwa ngaphandle kokuqulwa kwecala]
# [there is a common south african citizenship] => [kukhona ilungelo lobuzwe elifanayo lazo zonke izakhamuzi zaseningizimu afrika]
# [national flag] => [ifulegi lesizwe]
# [the rights in the bill of rights are subject to the limitations contained or referred to in section or elsewhere in the bill] => [amalungelo akumqulu wamalungelo angakhawulwa ngemikhawulo equkethwe noma okukhulunywe ngayo kwisigaba noma kwezinye izingxenye zomqulu]
# [or the privacy of their communications infringed] => [noma lokungaphazanyiswa kokuxhumana kwakhe nabanye abantu]
# [everyone has inherent dignity and the right to have their dignity respected and protected] => [wonke umuntu unesithunzi ngokwemvelo futhi unelungelo lokuthi isithunzi sakhe sihlonishwe futhi sivikelwe]
# [respect those who have worked to build and develop our country] => [sihlonipha labo abasebenzele ukwakha nokuthuthukisa izwe lethu]
# [everyone has the right peacefully and unarmed to assemble to demonstrate to picket and to present petitions] => [wonke umuntu unelungelo lokubuthana nabanye lokubhikisha lokugculisa abanye ukuthi beseke lowo mbhikisho nelokwethula izicelo ezibhaliwe kodwa uma lokho kwenziwa ngokuthula futhi kungahlonyiwe]
# [the state must respect protect promote and fulfil the rights in the bill of rights] => [umbuso kufanele uhloniphe uvikele uphakamise futhi uphelelise amalungelo akumqulu wamalungelo]
# [to make decisions concerning reproduction] => [lokwenza izinqumo ezimayelana nokuzala]
# [and open society in which government is based on the will of the people and every citizen is equally protected by law] => [futhi ovulekile lapho uhulumeni wakhelwe phezu kwentando yabantu futhi lapho sonke isakhamuzi sivikelwe ngumthetho ngendlela efanayo]
# [marriages concluded under any tradition or a system of religious personal or family law] => [imishado ehlanganiswe ngokwesiko noma ngokohlelo lomthetho wenkolo noma wemiphakathi ethile ebusa abantu nemindeni kuleyo miphakathi]
# [discrimination on one or more of the grounds listed in subsection is unfair unless it is established that the discrimination is fair] => [ubandlululo ngesizathu esisodwa noma ezingaphezulu ezibalululwe kwisigatshana akufanele ngaphandle uma kuboniswa ukuthi lolo bandlululo lufanele]
# [the official languages of the republic are sepedi sesotho setswana siswati tshivenda xitsonga afrikaans english isindebele isixhosa and isizulu] => [izilimi ezisemthethweni eningizimu afrika yisipedi isisuthu isitswana isiswazi isivenda isitsonga isibhunu isingisi isindebele isixhosa kanye nesizulu]
# [a pan south african language board established by national legislation must] => [ibhodi yezilimi zonke zaseningizimu afrika emiswe ngumthetho kazwelonke kufanele]
# [this section does not prevent legislation recognising] => [lesi sigaba asivimbeli umthetho ovumela]
# [rights] => [amalungelo]
# [human dignity] => [isithunzi sabantu]
# [ethnicity gender or religion and that constitutes incitement to cause harm] => [noma ukutshala umoya wenzondo ngokobuzwe ngokobuhlanga ubulili noma ngokwenkolo okudala inxushunxushu]
# [all citizens are] => [zonke izakhamuzi]
# [and not to be treated or punished in a cruel inhuman or degrading way] => [futhi lokungaphathwa noma ajeziswe ngendlela enesihluku engenabo ubuntu nelulazayo]
# [and promote and ensure respect for] => [futhi ikhuthaze futhi iqinisekise ukuhlonishwa kanye nokuthuthukiswa]
# [and to campaign for a political party or cause] => [futhi nokukhankasela iqembu lezombangazo noma izinjongo ezithile zepolitiki]
# [equality includes the full and equal enjoyment of all rights and freedoms] => [ukulingana kubandakanya ukuthokozela onke amalungelo nenkululeko ngokugcwele nangokulingana]
# [or systems of personal and family law under any tradition or adhered to by persons professing a particular religion] => [noma uhlelo lomthetho womphakathi othile obusa abantu nemindeni kuleyomiphakathi ngaphansi kwanoma yiliphi isiko noma oluhlonishwa abantu abalandela inkolo ethile]
# [they are conducted on an equitable basis] => [zibanjwe ngendlela efanele]
# [the national government and provincial governments by legislative and other measures must regulate and monitor their use of official languages] => [uhulumeni kazwelonke nabezifundazwe kufanele balawule futhi baqaphe ukusetshenziswa kwezilimi ezisemthethweni]
# [to participate in the activities of or recruit members for a political party] => [ukubamba iqhaza emisebenzini yenhlangano yezepolitiki noma ukuyifunela amalungu]
# [it enshrines the rights of all people in our country and affirms the democratic values of human dignity equality and freedom] => [ugcizelela amalungelo awowonke umuntu ezweni lethu futhi uqinisa inkolelo yenqubo yentando yeningi yokwazisa isithunzi somuntu ukulingana nokukhululeka]
# [practicality expense regional circumstances and the balance of the needs and preferences of the population as a whole or in the province concerned] => [ubunzima bokusebenzisa ezinye izilimi izindleko isimo sesifundazwe kanye nokuqhathaniswa kwezidingo nokukhethwa ngumphakathi uwonke noma kwisifundazwe esithintekile]
# [recognising the historically diminished use and status of the indigenous languages of our people the state must take practical and positive measures to elevate the status and advance the use of these languages] => [ngokubuka umlando wokwehliswa kokusetshenziswa nezinga lezilimi zendabuko zabantu bethu umbuso kufanele uthathe izinyathelo ezingasebenza nezinenqubekelaphambili zokuphakamisa izinga nokuthuthukisa ukusetshenziswa kwalezi zilimi]
# [promote and create conditions for the development and use of] => [ikhuthaze futhi yakhe izimo ezilungele ukuthuthukiswa nokusetshenziswa]
# [to security in and control over their body] => [lokuphepha komzimba nokuzilawulela umzimba]
# [slavery servitude and forced labour] => [ubugqili ukwesetshenziswa njengesigqila nokusetshenziswa ngenkani]
# [freedom and security of the person] => [inkululeko nokuphepha komuntu]
# [to form a political party] => [lokusungula iqembu lezepolitiki]
# [and equally subject to the duties and responsibilities of citizenship] => [futhi zethweswe ngokulinganayo izibopho nemithwalo ehambisana nobuzwe]
# [recognition in terms of paragraph must be consistent with this section and the other provisions of the constitution] => [imishado eyamukelwe noma izinhlelo zemithetho yemiphakathi ezamukelwe njengoba kusho isigatshana kufanele zihambisane nezimiso zomthethosisekelo]
# [assembly demonstration picket and petition] => [ukubuthana ukubhikisha ukugculisa abanye ukuthi beseke umbikisho nokwethula izicelo ezibhalwe phansi]
# [without detracting from the provisions of subsection all official languages must enjoy parity of esteem and must be treated equitably] => [ngaphandle kokususwa lokho okubekwa yisigatshana zonke izilimi ezisemthethweni kufanele zihlonishwe ngendlela elinganayo futhi zithathwe ngendlela efanele]
# [everyone has the right to freedom of expression which includes] => [wonke umuntu unelungelo lokuveza imibono yakhe ngokukhululeka okubandakanya]
# [to promote the achievement of equality legislative and other measures designed to protect or advance persons or categories of persons disadvantaged by unfair discrimination may be taken] => [ukuze kukhuthazwe impumelelo yelungelo lokulingana kungathathwa izinyathelo zokushaya imithetho nezinye izinyathelo okuqondwe ngazo ukuthi kuvikelwe noma kuthuthukiswe abantu noma imikhakha yabantu abancishiselwe amathuba ngenxa yobandlululo olungafanele]
# [the national government and provincial governments may use any particular official languages for the purposes of government taking into account usage] => [uhulumeni kazwelonke kanye nohulumeni wezifundazwe angasebenzisa izilimi ezithile ezisemthethweni emsebenzini kahulumeni ecabangela ukusetshenziswa kwalezo zilimi]
# [ethnic or social origin colour sexual orientation age disability religion conscience belief culture language and birth] => [isizwe kambe umphakathi umuntu adabuka kuwo ibala ubulili umuntu azifanisa noma afaniswa nabo iminyaka yobudala ukukhubazeka inkolo unembeza inkolelo isiko ulimi kanye nokuzalwa]
# [their property searched] => [lokungaseshwa kwempahla]
# [and attendance at them is free and voluntary] => [futhi ukuhambela lezo zinkonzo kungaphoqelelwe kodwa kungokokukhululeka nangokuzithandela]

# %% [markdown]
# # Split Text

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-german.pkl')

# reduce dataset size
n_sentences = 10000#35485
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9500], dataset[9500:]
# save
save_clean_data(dataset, 'english-german-both.pkl')
save_clean_data(train, 'english-german-train.pkl')
save_clean_data(test, 'english-german-test.pkl')
# Out:
# Saved: english-german-both.pkl
# Saved: english-german-train.pkl
# Saved: english-german-test.pkl

# %% [markdown]
# # Train Neural Translation Model

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# %%
# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# %%
# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('German Vocabulary Size: %d' % ger_vocab_size)
print('German Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
#encode 2k trainY batches at a time
print('type ', type(trainY))
print('Size of ' , len(trainY))
trainY = encode_output(trainY[:1000], eng_vocab_size)
print('first batch done')
# for i in range(2000,len(trainY),2000):
#     trainY = numpy.append(trainY, i)
#     print('first batch done')

    
# trainY = encode_output(trainY, eng_vocab_size)
# # prepare validation data
# testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
# testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
# #encode 2k testY batches at a time
# testY = encode_output(testY, eng_vocab_size)

# # define model
# model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
# model.compile(optimizer='adam', loss='categorical_crossentropy')
# # summarize defined model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)
# # fit model
# # filename ='model.h5' # '/content/drive/My Drive/Translator/model.h5'
# # pickle.dump(model, open(filename, 'wb'))
# # checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
# model.fit(trainX, trainY, epochs=1, batch_size=64, validation_data=(testX, testY),verbose=2)
# Out:
# English Vocabulary Size: 17444
# English Max Length: 105
# German Vocabulary Size: 40130
# German Max Length: 72
# type  <class 'numpy.ndarray'>
# Size of  9500

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
# model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer,trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
